# %%
# %sql
--use catalog (free trial is not possible to use UC)
USE CATALOG hive_metastore;

--creat layers
CREATE SCHEMA IF NOT EXISTS abinbev_case_bronze;
CREATE SCHEMA IF NOT EXISTS abinbev_case_silver;
CREATE SCHEMA IF NOT EXISTS abinbev_case_gold;

--initial schema
USE SCHEMA abinbev_case_bronze;

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/abinbev_case/raw/")
dbutils.fs.mkdirs("dbfs:/FileStore/abinbev_case/bronze/")
dbutils.fs.mkdirs("dbfs:/FileStore/abinbev_case/silver/")
dbutils.fs.mkdirs("dbfs:/FileStore/abinbev_case/gold/")
print("Estrutura de pastas criada com sucesso!")

# %%
dbutils.fs.ls("dbfs:/FileStore/tables/")

# %%
# %sql
DESCRIBE TABLE abinbev_case_bronze.beverage_channel_group;

# %%
# %sql
DESCRIBE TABLE abinbev_case_bronze.beverage_sales;
